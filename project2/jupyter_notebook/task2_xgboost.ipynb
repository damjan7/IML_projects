# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.metrics import roc_auc_score as auc
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn import svm
from xgboost import XGBRegressor
from xgboost import XGBClassifier

pd.set_option('display.max_columns', 500)

# %%
# Importing the Data

train_features = pd.read_csv('train_features.csv')
train_labels = pd.read_csv('train_labels.csv')
test_features = pd.read_csv('test_features.csv')

# %%
Y = train_labels.sort_values('pid')
X = train_features.sort_values(['pid', 'Time'])
X_test =  test_features.sort_values(['pid', 'Time'])

#all labels
x_for_y_names = ['pid', "BaseExcess", "Fibrinogen",
		"AST", "Alkalinephos", "Bilirubin_total",
		"Lactate", "TroponinI", "SaO2", 
		"Bilirubin_direct", "EtCO2", 
		'RRate', 'ABPm', 'SpO2', 'Heartrate']
x_lag = X[x_for_y_names]
x_test_lag = X_test[x_for_y_names]

# %%
sum(np.isnan(X['EtCO2'])) / len(X['EtCO2'])
# Out:
# 0.9570808107396683

# %%
x_lag
# Out:
#           pid  BaseExcess  Fibrinogen  AST  Alkalinephos  Bilirubin_total  \
# 0           1        -2.0         NaN  NaN           NaN              NaN
# 1           1        -2.0         NaN  NaN           NaN              NaN
# 2           1         0.0         NaN  NaN           NaN              NaN
# 3           1         0.0         NaN  NaN           NaN              NaN
# 4           1         NaN         NaN  NaN           NaN              NaN
# ...       ...         ...         ...  ...           ...              ...
# 172879  31658         NaN         NaN  NaN           NaN              NaN
# 172880  31658         NaN         NaN  NaN           NaN              NaN
# 172881  31658         NaN         NaN  NaN           NaN              NaN
# 172882  31658         NaN         NaN  NaN           NaN              NaN
# 172883  31658         NaN         NaN  NaN           NaN              NaN
#
#         Lactate  TroponinI  SaO2  Bilirubin_direct  EtCO2  RRate   ABPm  \
# 0           NaN        NaN   NaN               NaN    NaN   16.0   84.0
# 1           NaN        NaN   NaN               NaN    NaN   16.0   81.0
# 2           NaN        NaN   NaN               NaN    NaN   18.0   74.0
# 3           NaN        NaN   NaN               NaN    NaN   18.0   66.0
# 4           NaN        NaN   NaN               NaN    NaN   18.0   63.0
# ...         ...        ...   ...               ...    ...    ...    ...
# 172879      NaN        NaN   NaN               NaN    NaN    NaN   91.0
# 172880      NaN        NaN   NaN               NaN    NaN    NaN    NaN
# 172881      NaN        NaN   NaN               NaN    NaN    NaN    NaN
# 172882      NaN        NaN   NaN               NaN    NaN    NaN  108.0
# 172883      NaN        NaN   NaN               NaN    NaN    NaN  108.0
#
#          SpO2  Heartrate
# 0       100.0       94.0
# 1       100.0       99.0
# 2       100.0       92.0
# 3       100.0       88.0
# 4       100.0       81.0
# ...       ...        ...
# 172879   96.0       71.0
# 172880    NaN        NaN
# 172881    NaN        NaN
# 172882   96.0       71.0
# 172883   96.0       71.0
#
# [227940 rows x 15 columns]

# %%
shifted = x_lag.groupby('pid').shift(+1)
shifted.columns = ["BaseExcess_lag", "Fibrinogen_lag",
		"AST_lag", "Alkalinephos_lag", "Bilirubin_total_lag",
		"Lactate_lag", "TroponinI_lag", "SaO2_lag", 
		"Bilirubin_direct_lag", "EtCO2_lag",'RRate_lag', 
		'ABPm_lag', 'SpO2_lag', 'Heartrate_lag']

shifted_T = x_test_lag.groupby('pid').shift(+1)
shifted_T.columns = ["BaseExcess_lag", "Fibrinogen_lag",
		"AST_lag", "Alkalinephos_lag", "Bilirubin_total_lag",
		"Lactate_lag", "TroponinI_lag", "SaO2_lag", 
		"Bilirubin_direct_lag", "EtCO2_lag",'RRate_lag', 
		'ABPm_lag', 'SpO2_lag', 'Heartrate_lag']

X = pd.concat([X, shifted], axis = 1)
X_test = pd.concat([X_test, shifted_T], axis = 1)

X_fit = X.groupby('pid', group_keys = False).mean()
X_test_fit = X_test.groupby('pid', group_keys = False).mean()
r_pid = pd.Series(X_fit.index.copy()).astype('int')
r_pid_T = pd.Series(X_test_fit.index.copy()).astype('int')

X_fit.index = range(X_fit.shape[0])
X_test_fit.index = range(X_test_fit.shape[0])

X_fit = pd.concat([r_pid, X_fit], axis = 1)
X_test_fit = pd.concat([r_pid_T, X_test_fit], axis = 1)

# %%
X_fit
# Out:
#          pid  Time   Age  EtCO2   PTT   BUN  Lactate       Temp        Hgb  \
# 0          1   8.5  34.0    NaN   NaN  12.0      NaN  36.750000   8.566667
# 1          2   6.5  86.0    NaN  31.8  32.0      NaN  36.000000  13.100000
# 2          4   6.5  66.0    NaN  34.6   8.0      NaN  36.666667  10.550000
# 3          6   7.5  66.0    NaN  53.8  32.0      1.8  37.166667  10.316667
# 4          8   6.5  42.0    NaN   NaN  18.0      NaN  36.000000        NaN
# ...      ...   ...   ...    ...   ...   ...      ...        ...        ...
# 18990  31653   6.5  52.0    NaN  25.8  11.0      1.7  36.000000   9.500000
# 18991  31654   6.5  66.0    NaN   NaN  33.0      NaN  37.500000  11.200000
# 18992  31656   6.5  44.0    NaN   NaN  15.0      NaN  38.000000  12.400000
# 18993  31657   6.5  70.0    NaN   NaN   NaN      NaN  36.500000        NaN
# 18994  31658   6.5  60.0    NaN   NaN  13.0      NaN  36.500000  14.400000
#
#             HCO3  BaseExcess      RRate  Fibrinogen  Phosphate        WBC  \
# 0      25.333333   -0.666667  17.000000         NaN       4.60   5.233333
# 1            NaN         NaN  18.000000         NaN       3.80   9.300000
# 2            NaN         NaN  14.636364         NaN       3.10   7.500000
# 3      19.500000   -2.857143  15.833333         NaN       3.10  39.700000
# 4            NaN         NaN  17.181818         NaN       3.30        NaN
# ...          ...         ...        ...         ...        ...        ...
# 18990  22.666667    0.000000  15.545455       633.0       4.40  16.033333
# 18991        NaN         NaN  16.909091         NaN       5.45   2.000000
# 18992  24.000000   -3.500000  24.900000         NaN        NaN  24.000000
# 18993        NaN         NaN  15.500000         NaN        NaN        NaN
# 18994        NaN         NaN        NaN         NaN        NaN   4.600000
#
#        Creatinine      PaCO2   AST      FiO2  Platelets  SaO2     Glucose  \
# 0           0.500  43.333333   NaN  0.425000      143.0   NaN  120.000000
# 1           2.120        NaN   NaN       NaN      226.0   NaN  111.000000
# 2           0.530        NaN  34.0       NaN      269.0   NaN  100.166667
# 3           1.350  39.000000   NaN  0.566667      105.0  95.0  113.500000
# 4           6.460        NaN   NaN       NaN        NaN   NaN  118.000000
# ...           ...        ...   ...       ...        ...   ...         ...
# 18990       0.700  49.000000   NaN       NaN      489.0   NaN  137.000000
# 18991      10.335        NaN   NaN       NaN      124.0   NaN   87.500000
# 18992       0.700  45.250000   NaN  0.400000      345.0   NaN  115.000000
# 18993         NaN        NaN   NaN       NaN        NaN   NaN         NaN
# 18994       0.710        NaN   NaN       NaN      164.0   NaN  104.000000
#
#              ABPm  Magnesium  Potassium        ABPd  Calcium  Alkalinephos  \
# 0       68.333333       1.80   4.000000   50.250000      7.6           NaN
# 1       94.636364       2.10   3.800000   70.090909      9.5           NaN
# 2       80.909091       2.45   3.500000   49.600000      8.2         130.0
# 3       65.750000       3.10   4.633333   48.833333      7.8           NaN
# 4      143.900000       2.10   4.300000  108.954545      7.9           NaN
# ...           ...        ...        ...         ...      ...           ...
# 18990   65.636364       2.20   4.866667   49.166667      7.9           NaN
# 18991  122.363636       2.10   5.700000   94.181818      8.5           NaN
# 18992   78.600000        NaN   4.000000   63.900000      NaN           NaN
# 18993   73.600000        NaN        NaN   62.900000      NaN           NaN
# 18994   99.500000       1.90   3.600000   74.333333      8.8           NaN
#
#              SpO2  Bilirubin_direct  Chloride    Hct   Heartrate  \
# 0      100.000000               NaN     112.0  23.20   77.083333
# 1       96.000000               NaN       NaN  40.20   59.000000
# 2       99.272727               0.1       NaN  33.55   72.545455
# 3       99.333333               NaN     113.5  30.39   87.333333
# 4       97.800000               NaN       NaN    NaN   81.181818
# ...           ...               ...       ...    ...         ...
# 18990   96.181818               NaN     106.0  31.56  108.272727
# 18991   96.090909               NaN       NaN  34.60   92.909091
# 18992  100.000000               NaN      97.0  36.70   99.100000
# 18993   99.100000               NaN       NaN    NaN   64.400000
# 18994   96.000000               NaN       NaN  40.20   68.000000
#
#        Bilirubin_total  TroponinI        ABPs        pH  BaseExcess_lag  \
# 0                  NaN        NaN  114.500000  7.370000       -0.666667
# 1                  NaN       0.44  131.181818       NaN             NaN
# 2                  0.6       0.02  125.454545       NaN             NaN
# 3                  NaN        NaN  100.666667  7.352857       -2.857143
# 4                  NaN       0.08  204.545455       NaN             NaN
# ...                ...        ...         ...       ...             ...
# 18990              NaN        NaN   87.333333  7.330000        0.000000
# 18991              NaN        NaN  165.000000       NaN             NaN
# 18992              NaN        NaN  100.300000  7.300000       -3.500000
# 18993              NaN        NaN  110.500000       NaN             NaN
# 18994              NaN        NaN  133.000000       NaN             NaN
#
#        Fibrinogen_lag  AST_lag  Alkalinephos_lag  Bilirubin_total_lag  \
# 0                 NaN      NaN               NaN                  NaN
# 1                 NaN      NaN               NaN                  NaN
# 2                 NaN     34.0             130.0                  0.6
# 3                 NaN      NaN               NaN                  NaN
# 4                 NaN      NaN               NaN                  NaN
# ...               ...      ...               ...                  ...
# 18990           633.0      NaN               NaN                  NaN
# 18991             NaN      NaN               NaN                  NaN
# 18992             NaN      NaN               NaN                  NaN
# 18993             NaN      NaN               NaN                  NaN
# 18994             NaN      NaN               NaN                  NaN
#
#        Lactate_lag  TroponinI_lag  SaO2_lag  Bilirubin_direct_lag  EtCO2_lag  \
# 0              NaN            NaN       NaN                   NaN        NaN
# 1              NaN           0.44       NaN                   NaN        NaN
# 2              NaN           0.02       NaN                   0.1        NaN
# 3              1.8            NaN      95.0                   NaN        NaN
# 4              NaN           0.08       NaN                   NaN        NaN
# ...            ...            ...       ...                   ...        ...
# 18990          1.7            NaN       NaN                   NaN        NaN
# 18991          NaN            NaN       NaN                   NaN        NaN
# 18992          NaN            NaN       NaN                   NaN        NaN
# 18993          NaN            NaN       NaN                   NaN        NaN
# 18994          NaN            NaN       NaN                   NaN        NaN
#
#        RRate_lag    ABPm_lag    SpO2_lag  Heartrate_lag
# 0      16.909091   69.727273  100.000000      77.818182
# 1      17.900000   94.200000   96.200000      59.000000
# 2      14.700000   82.800000   99.500000      72.600000
# 3      15.272727   65.636364   99.454545      87.090909
# 4      17.300000  142.777778   97.777778      81.200000
# ...          ...         ...         ...            ...
# 18990  14.600000   63.300000   96.500000     104.300000
# 18991  17.100000  123.500000   96.000000      93.200000
# 18992  24.900000   78.600000  100.000000      99.100000
# 18993  15.000000   74.111111   99.111111      64.555556
# 18994        NaN   96.666667   96.000000      67.400000
#
# [18995 rows x 51 columns]

# %%
X
# Out:
#           pid  Time   Age  EtCO2  PTT   BUN  Lactate  Temp  Hgb  HCO3  \
# 0           1     3  34.0    NaN  NaN  12.0      NaN  36.0  8.7  24.0
# 1           1     4  34.0    NaN  NaN   NaN      NaN  36.0  NaN   NaN
# 2           1     5  34.0    NaN  NaN   NaN      NaN  36.0  NaN   NaN
# 3           1     6  34.0    NaN  NaN   NaN      NaN  37.0  NaN   NaN
# 4           1     7  34.0    NaN  NaN   NaN      NaN   NaN  NaN   NaN
# ...       ...   ...   ...    ...  ...   ...      ...   ...  ...   ...
# 172879  31658     8  60.0    NaN  NaN   NaN      NaN  37.0  NaN   NaN
# 172880  31658     9  60.0    NaN  NaN   NaN      NaN   NaN  NaN   NaN
# 172881  31658    10  60.0    NaN  NaN   NaN      NaN   NaN  NaN   NaN
# 172882  31658    11  60.0    NaN  NaN   NaN      NaN   NaN  NaN   NaN
# 172883  31658    12  60.0    NaN  NaN   NaN      NaN   NaN  NaN   NaN
#
#         BaseExcess  RRate  Fibrinogen  Phosphate  WBC  Creatinine  PaCO2  AST  \
# 0             -2.0   16.0         NaN        NaN  6.3         NaN   45.0  NaN
# 1             -2.0   16.0         NaN        NaN  NaN         NaN    NaN  NaN
# 2              0.0   18.0         NaN        NaN  NaN         NaN   43.0  NaN
# 3              0.0   18.0         NaN        NaN  NaN         NaN    NaN  NaN
# 4              NaN   18.0         NaN        NaN  NaN         NaN    NaN  NaN
# ...            ...    ...         ...        ...  ...         ...    ...  ...
# 172879         NaN    NaN         NaN        NaN  NaN         NaN    NaN  NaN
# 172880         NaN    NaN         NaN        NaN  NaN         NaN    NaN  NaN
# 172881         NaN    NaN         NaN        NaN  NaN         NaN    NaN  NaN
# 172882         NaN    NaN         NaN        NaN  NaN         NaN    NaN  NaN
# 172883         NaN    NaN         NaN        NaN  NaN         NaN    NaN  NaN
#
#         FiO2  Platelets  SaO2  Glucose   ABPm  Magnesium  Potassium  ABPd  \
# 0        NaN        NaN   NaN      NaN   84.0        1.2        3.8  61.0
# 1        0.5        NaN   NaN      NaN   81.0        NaN        NaN  62.5
# 2        0.4        NaN   NaN      NaN   74.0        NaN        NaN  59.0
# 3        NaN        NaN   NaN      NaN   66.0        NaN        NaN  49.5
# 4        NaN        NaN   NaN      NaN   63.0        1.8        NaN  48.0
# ...      ...        ...   ...      ...    ...        ...        ...   ...
# 172879   NaN        NaN   NaN      NaN   91.0        NaN        NaN  70.0
# 172880   NaN        NaN   NaN      NaN    NaN        NaN        NaN   NaN
# 172881   NaN        NaN   NaN      NaN    NaN        NaN        NaN   NaN
# 172882   NaN        NaN   NaN    110.0  108.0        NaN        NaN  81.0
# 172883   NaN        NaN   NaN      NaN  108.0        NaN        NaN  81.0
#
#         Calcium  Alkalinephos   SpO2  Bilirubin_direct  Chloride   Hct  \
# 0           NaN           NaN  100.0               NaN     114.0  24.6
# 1           NaN           NaN  100.0               NaN       NaN   NaN
# 2           NaN           NaN  100.0               NaN       NaN   NaN
# 3           NaN           NaN  100.0               NaN       NaN   NaN
# 4           NaN           NaN  100.0               NaN       NaN  22.4
# ...         ...           ...    ...               ...       ...   ...
# 172879      NaN           NaN   96.0               NaN       NaN   NaN
# 172880      NaN           NaN    NaN               NaN       NaN   NaN
# 172881      NaN           NaN    NaN               NaN       NaN   NaN
# 172882      NaN           NaN   96.0               NaN       NaN   NaN
# 172883      NaN           NaN   96.0               NaN       NaN   NaN
#
#         Heartrate  Bilirubin_total  TroponinI   ABPs    pH  BaseExcess_lag  \
# 0            94.0              NaN        NaN  142.0  7.33             NaN
# 1            99.0              NaN        NaN  125.0  7.33            -2.0
# 2            92.0              NaN        NaN  110.0  7.37            -2.0
# 3            88.0              NaN        NaN  104.0  7.37             0.0
# 4            81.0              NaN        NaN  100.0  7.41             0.0
# ...           ...              ...        ...    ...   ...             ...
# 172879       71.0              NaN        NaN  127.0   NaN             NaN
# 172880        NaN              NaN        NaN    NaN   NaN             NaN
# 172881        NaN              NaN        NaN    NaN   NaN             NaN
# 172882       71.0              NaN        NaN  135.0   NaN             NaN
# 172883       71.0              NaN        NaN  135.0   NaN             NaN
#
#         Fibrinogen_lag  AST_lag  Alkalinephos_lag  Bilirubin_total_lag  \
# 0                  NaN      NaN               NaN                  NaN
# 1                  NaN      NaN               NaN                  NaN
# 2                  NaN      NaN               NaN                  NaN
# 3                  NaN      NaN               NaN                  NaN
# 4                  NaN      NaN               NaN                  NaN
# ...                ...      ...               ...                  ...
# 172879             NaN      NaN               NaN                  NaN
# 172880             NaN      NaN               NaN                  NaN
# 172881             NaN      NaN               NaN                  NaN
# 172882             NaN      NaN               NaN                  NaN
# 172883             NaN      NaN               NaN                  NaN
#
#         Lactate_lag  TroponinI_lag  SaO2_lag  Bilirubin_direct_lag  EtCO2_lag  \
# 0               NaN            NaN       NaN                   NaN        NaN
# 1               NaN            NaN       NaN                   NaN        NaN
# 2               NaN            NaN       NaN                   NaN        NaN
# 3               NaN            NaN       NaN                   NaN        NaN
# 4               NaN            NaN       NaN                   NaN        NaN
# ...             ...            ...       ...                   ...        ...
# 172879          NaN            NaN       NaN                   NaN        NaN
# 172880          NaN            NaN       NaN                   NaN        NaN
# 172881          NaN            NaN       NaN                   NaN        NaN
# 172882          NaN            NaN       NaN                   NaN        NaN
# 172883          NaN            NaN       NaN                   NaN        NaN
#
#         RRate_lag  ABPm_lag  SpO2_lag  Heartrate_lag
# 0             NaN       NaN       NaN            NaN
# 1            16.0      84.0     100.0           94.0
# 2            16.0      81.0     100.0           99.0
# 3            18.0      74.0     100.0           92.0
# 4            18.0      66.0     100.0           88.0
# ...           ...       ...       ...            ...
# 172879        NaN      91.0      96.0           71.0
# 172880        NaN      91.0      96.0           71.0
# 172881        NaN       NaN       NaN            NaN
# 172882        NaN       NaN       NaN            NaN
# 172883        NaN     108.0      96.0           71.0
#
# [227940 rows x 51 columns]

# %%
X_fit = X_fit.drop(['pid', 'Time'], axis = 1)
X_test_pid = X_test_fit['pid']
X_test_fit = X_test_fit.drop(['pid', 'Time'], axis = 1)

# %%
X_fit
# Out:
#         Age  EtCO2   PTT   BUN  Lactate       Temp        Hgb       HCO3  \
# 0      34.0    NaN   NaN  12.0      NaN  36.750000   8.566667  25.333333
# 1      86.0    NaN  31.8  32.0      NaN  36.000000  13.100000        NaN
# 2      66.0    NaN  34.6   8.0      NaN  36.666667  10.550000        NaN
# 3      66.0    NaN  53.8  32.0      1.8  37.166667  10.316667  19.500000
# 4      42.0    NaN   NaN  18.0      NaN  36.000000        NaN        NaN
# ...     ...    ...   ...   ...      ...        ...        ...        ...
# 18990  52.0    NaN  25.8  11.0      1.7  36.000000   9.500000  22.666667
# 18991  66.0    NaN   NaN  33.0      NaN  37.500000  11.200000        NaN
# 18992  44.0    NaN   NaN  15.0      NaN  38.000000  12.400000  24.000000
# 18993  70.0    NaN   NaN   NaN      NaN  36.500000        NaN        NaN
# 18994  60.0    NaN   NaN  13.0      NaN  36.500000  14.400000        NaN
#
#        BaseExcess      RRate  Fibrinogen  Phosphate        WBC  Creatinine  \
# 0       -0.666667  17.000000         NaN       4.60   5.233333       0.500
# 1             NaN  18.000000         NaN       3.80   9.300000       2.120
# 2             NaN  14.636364         NaN       3.10   7.500000       0.530
# 3       -2.857143  15.833333         NaN       3.10  39.700000       1.350
# 4             NaN  17.181818         NaN       3.30        NaN       6.460
# ...           ...        ...         ...        ...        ...         ...
# 18990    0.000000  15.545455       633.0       4.40  16.033333       0.700
# 18991         NaN  16.909091         NaN       5.45   2.000000      10.335
# 18992   -3.500000  24.900000         NaN        NaN  24.000000       0.700
# 18993         NaN  15.500000         NaN        NaN        NaN         NaN
# 18994         NaN        NaN         NaN        NaN   4.600000       0.710
#
#            PaCO2   AST      FiO2  Platelets  SaO2     Glucose        ABPm  \
# 0      43.333333   NaN  0.425000      143.0   NaN  120.000000   68.333333
# 1            NaN   NaN       NaN      226.0   NaN  111.000000   94.636364
# 2            NaN  34.0       NaN      269.0   NaN  100.166667   80.909091
# 3      39.000000   NaN  0.566667      105.0  95.0  113.500000   65.750000
# 4            NaN   NaN       NaN        NaN   NaN  118.000000  143.900000
# ...          ...   ...       ...        ...   ...         ...         ...
# 18990  49.000000   NaN       NaN      489.0   NaN  137.000000   65.636364
# 18991        NaN   NaN       NaN      124.0   NaN   87.500000  122.363636
# 18992  45.250000   NaN  0.400000      345.0   NaN  115.000000   78.600000
# 18993        NaN   NaN       NaN        NaN   NaN         NaN   73.600000
# 18994        NaN   NaN       NaN      164.0   NaN  104.000000   99.500000
#
#        Magnesium  Potassium        ABPd  Calcium  Alkalinephos        SpO2  \
# 0           1.80   4.000000   50.250000      7.6           NaN  100.000000
# 1           2.10   3.800000   70.090909      9.5           NaN   96.000000
# 2           2.45   3.500000   49.600000      8.2         130.0   99.272727
# 3           3.10   4.633333   48.833333      7.8           NaN   99.333333
# 4           2.10   4.300000  108.954545      7.9           NaN   97.800000
# ...          ...        ...         ...      ...           ...         ...
# 18990       2.20   4.866667   49.166667      7.9           NaN   96.181818
# 18991       2.10   5.700000   94.181818      8.5           NaN   96.090909
# 18992        NaN   4.000000   63.900000      NaN           NaN  100.000000
# 18993        NaN        NaN   62.900000      NaN           NaN   99.100000
# 18994       1.90   3.600000   74.333333      8.8           NaN   96.000000
#
#        Bilirubin_direct  Chloride    Hct   Heartrate  Bilirubin_total  \
# 0                   NaN     112.0  23.20   77.083333              NaN
# 1                   NaN       NaN  40.20   59.000000              NaN
# 2                   0.1       NaN  33.55   72.545455              0.6
# 3                   NaN     113.5  30.39   87.333333              NaN
# 4                   NaN       NaN    NaN   81.181818              NaN
# ...                 ...       ...    ...         ...              ...
# 18990               NaN     106.0  31.56  108.272727              NaN
# 18991               NaN       NaN  34.60   92.909091              NaN
# 18992               NaN      97.0  36.70   99.100000              NaN
# 18993               NaN       NaN    NaN   64.400000              NaN
# 18994               NaN       NaN  40.20   68.000000              NaN
#
#        TroponinI        ABPs        pH  BaseExcess_lag  Fibrinogen_lag  \
# 0            NaN  114.500000  7.370000       -0.666667             NaN
# 1           0.44  131.181818       NaN             NaN             NaN
# 2           0.02  125.454545       NaN             NaN             NaN
# 3            NaN  100.666667  7.352857       -2.857143             NaN
# 4           0.08  204.545455       NaN             NaN             NaN
# ...          ...         ...       ...             ...             ...
# 18990        NaN   87.333333  7.330000        0.000000           633.0
# 18991        NaN  165.000000       NaN             NaN             NaN
# 18992        NaN  100.300000  7.300000       -3.500000             NaN
# 18993        NaN  110.500000       NaN             NaN             NaN
# 18994        NaN  133.000000       NaN             NaN             NaN
#
#        AST_lag  Alkalinephos_lag  Bilirubin_total_lag  Lactate_lag  \
# 0          NaN               NaN                  NaN          NaN
# 1          NaN               NaN                  NaN          NaN
# 2         34.0             130.0                  0.6          NaN
# 3          NaN               NaN                  NaN          1.8
# 4          NaN               NaN                  NaN          NaN
# ...        ...               ...                  ...          ...
# 18990      NaN               NaN                  NaN          1.7
# 18991      NaN               NaN                  NaN          NaN
# 18992      NaN               NaN                  NaN          NaN
# 18993      NaN               NaN                  NaN          NaN
# 18994      NaN               NaN                  NaN          NaN
#
#        TroponinI_lag  SaO2_lag  Bilirubin_direct_lag  EtCO2_lag  RRate_lag  \
# 0                NaN       NaN                   NaN        NaN  16.909091
# 1               0.44       NaN                   NaN        NaN  17.900000
# 2               0.02       NaN                   0.1        NaN  14.700000
# 3                NaN      95.0                   NaN        NaN  15.272727
# 4               0.08       NaN                   NaN        NaN  17.300000
# ...              ...       ...                   ...        ...        ...
# 18990            NaN       NaN                   NaN        NaN  14.600000
# 18991            NaN       NaN                   NaN        NaN  17.100000
# 18992            NaN       NaN                   NaN        NaN  24.900000
# 18993            NaN       NaN                   NaN        NaN  15.000000
# 18994            NaN       NaN                   NaN        NaN        NaN
#
#          ABPm_lag    SpO2_lag  Heartrate_lag
# 0       69.727273  100.000000      77.818182
# 1       94.200000   96.200000      59.000000
# 2       82.800000   99.500000      72.600000
# 3       65.636364   99.454545      87.090909
# 4      142.777778   97.777778      81.200000
# ...           ...         ...            ...
# 18990   63.300000   96.500000     104.300000
# 18991  123.500000   96.000000      93.200000
# 18992   78.600000  100.000000      99.100000
# 18993   74.111111   99.111111      64.555556
# 18994   96.666667   96.000000      67.400000
#
# [18995 rows x 49 columns]

# %%
n_class = ["LABEL_BaseExcess", "LABEL_Fibrinogen",
		"LABEL_AST", "LABEL_Alkalinephos", "LABEL_Bilirubin_total",
		"LABEL_Lactate", "LABEL_TroponinI", "LABEL_SaO2", 
		"LABEL_Bilirubin_direct", "LABEL_EtCO2", "LABEL_Sepsis"]

# %%
i = 0
output_classifiaction = np.zeros((X_test_fit.shape[0], len(n_class)))
for y_name in n_class:

	# Model Fitting
	# ------------------------------------------------------------------------------------------------
	rf_model = XGBClassifier()
	y_fit = Y[y_name]


	rf_model.fit(X_fit, y_fit)
	y_test_p = rf_model.predict_proba(X_test_fit)
	output_classifiaction[:,i] = y_test_p[:,1]
	i = i + 1

output_classifiaction = pd.DataFrame(output_classifiaction)
output_classifiaction.columns = n_class
# Out:
# C:\Users\Damja\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12:45:02] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:04] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:07] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:09] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:11] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:14] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:17] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:20] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:23] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:26] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:45:29] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
